# %%
# %load_ext autoreload
# %autoreload 2
import animar
from IPython.display import HTML
# Out:
# Para ayuda de como utilizar animar ejecute animar.help()

# %%
animar.help()
# Out:
# Este modulo es un frontend de matplotlib para facilitar el grafico de funciones dependientes del tiempo.
# Para ejecutarlo se deben tener definidas funciones de la forma f=f(x,t) dependientes de x y de t donde se recorre los graficos modificando el valor de t.
# animar.estacionaria es un ejemplo preconstruido de onda estacionaria.
# animar.viajera es un ejemplo preconstruido de onda viajera.
# animar.gauss_viajera es un ejemplo preconstruido de una gaussiana viajera.
# Para visualizar las funciones en el entorno de jupyter notebook se debe convertir a formato HTML las animaciones. Para ello se debe importar ´from IPython.display import HTML´ y luego ejecutar ´HTML(anim.to_html5_video())´ donde anim es la animacion creada con ´anim = animar.animar(f)´.
# El paquete animar posee parametros default que se enuncian a continuacion, si se desean modificar se deden sobreescribir al crear la animación.
#
#
#     x_ini = 0
#
#     x_fin = 1
#
#     dx = 0.01
#
#     t_ini = 0
#
# ...

# %%
HTML(animar.animar(animar.viajera,x_ini=-3,x_fin=3).to_html5_video())
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...
